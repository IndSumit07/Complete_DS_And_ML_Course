# %% [markdown]
# # Function Example

# %% [markdown]
# ### Example 1: Temperature Conversion

# %%
def convert_temperature(temp, unit):
    """This function converts temperrature between Celcius and Farenheit"""

    if unit=='C':
        return temp*9/5 + 32 # Celicius to farenheit
    elif unit=='F':
        return (temp-32)*5/9
    else:
        return None

print(convert_temperature(25, 'C'))
print(convert_temperature(77, 'F'))
# Out:
# 77.0
# 25.0

# %% [markdown]
# ### Example 2: Password Strength Checker

# %%
def is_strong_password(password):
    if len(password)<8:
        return False;
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    return True

# %%
print(is_strong_password("MainSumitHoon"))
print(is_strong_password("Developer@2005@Sumit@2005@VSCode"))
# Out:
# False
# True
