# %%
a=10
b=10.5
c="Sumit"
d=True
# Out:
# Hello

# %%
value='25'
num=int(value)
print(num)
# Out:
# 25

# %%
name="Sumit"
num=int(name)
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 name="Sumit"
# ----> 2 num=int(name)
#       3 print(num)
#
# ValueError: invalid literal for int() with base 10: 'Sumit'

# %%
height=6.1
int_height=int(height)
print(int_height)
# Out:
# 6

# %%
## Dynamic Typing - Python allows to change the type of varibales as the program executes

var = 10
print(var, type(var))

var="Sumit"
print(var, type(var))
# Out:
# 10 <class 'int'>
# Sumit <class 'str'>

# %%
age = int(input("What is your age: "));
print(age, type(age))
# Out:
# 5 <class 'int'>
