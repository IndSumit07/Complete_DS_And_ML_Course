# %%
## Line Continuation
sum = 1+2+3+\
4+6

mult = 2*2*2*\
2*2
print(mult)
# Out:
# 32

# %%
# Multiple statemnets on a single line
x=5;y=10;z=20;c=x+y+z;print(c)
# Out:
# 35

# %%
# Type Inference

variable = 10
print(type(variable))
variable = 10.0
print(type(variable))
variable = "Sumit Kumar"
print(type(variable))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# Name error - If a variable is not defined and we try to use that variable
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Name error - If a variable is not defined and we try to use that variable
# ----> 3 a=b
#
# NameError: name 'b' is not defined
