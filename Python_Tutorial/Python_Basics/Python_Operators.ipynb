# %%
a=10
b=5

addition=a+b
substraction=a-b
multiplication=a*b
division=a/b
floor_division=a//b
modulus=a%b
exponent=a**b

print(addition)
print(substraction)
print(multiplication)
print(division)
print(floor_division)
print(modulus)
print(exponent)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
# Out:
# True
